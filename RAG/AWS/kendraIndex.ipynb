# %%
import os
import boto3
from botocore.exceptions import ClientError

# %%
INDEX_ID = "07c93565-dba9-4902-8077-673c1c09e241"
REGION   = os.environ.get("AWS_REGION", "us-east-1")

def kendra_client(
    region=REGION,
    *,
    access_key: str | None = None,
    secret_key: str | None = None,
    session_token: str | None = None,
    profile: str | None = None,
    role_arn: str | None = None,
):
    """
    Returns a boto3 Kendra client.

    Credential resolution (first match wins):
    1) Explicit long-lived keys passed as args (access_key/secret_key[/session_token])
    2) Named AWS profile (profile)
    3) Default boto3 chain (env vars, ~/.aws/credentials, EC2/ECS role, etc.)
    4) Assume role (role_arn)  -> STS temporary creds

    Notes:
    - For *permanent method*, pass access_key + secret_key, or set them via the AWS
      standard mechanisms (env vars / ~/.aws/credentials).
    - If role_arn is provided, it will be used only when no explicit keys or profile are given.
    """

    # --- 1) Explicit key pair (permanent or temp) ---
    if access_key and secret_key:
        return boto3.client(
            "kendra",
            region_name=region,
            aws_access_key_id=access_key,
            aws_secret_access_key=secret_key,
            # aws_session_token=session_token,  # usually None for long-lived keys
        )

    # --- 2) Specific AWS profile ---
    if profile:
        session = boto3.Session(profile_name=profile)
        return session.client("kendra", region_name=region)

    # --- 3) Default chain (env vars / shared config / instance role) ---
    # If your long-lived keys are in env vars or ~/.aws/credentials, this covers it.
    session = boto3.Session()
    if not role_arn:
        return session.client("kendra", region_name=region)

    # --- 4) Assume role (fallback if requested) ---
    sts = session.client("sts", region_name=region)
    creds = sts.assume_role(RoleArn=role_arn, RoleSessionName="kendra-session")["Credentials"]
    return boto3.client(
        "kendra",
        region_name=region,
        aws_access_key_id=creds["AccessKeyId"],
        aws_secret_access_key=creds["SecretAccessKey"],
        aws_session_token=creds["SessionToken"],
    )

client = kendra_client(
    # Option A (Permanent): pass your long-lived keys directly (recommended only if you must):
    access_key=os.getenv("AWS_ACCESS_KEY_ID"),
    secret_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
)

try:
    info = client.describe_index(Id=INDEX_ID)
    status  = info.get("Status")
    name    = info.get("Name")
    edition = info.get("Edition")
    print(f"Connected to Kendra index: {name} ({INDEX_ID}), edition={edition}, status={status}")
except ClientError as e:
    print(f"DescribeIndex failed: {e.response.get('Error', {}).get('Message', str(e))}")
    raise
# Out:
# Connected to Kendra index: ndIndex (07c93565-dba9-4902-8077-673c1c09e241), edition=GEN_AI_ENTERPRISE_EDITION, status=ACTIVE

# %%
def run_query(query_text, page_size=10, query_filter=None, user_groups=None):
    """
    Runs Kendra Query and prints top results (documents + answers).
    - query_filter: optional AttributeFilter dict (e.g., filter by data source, date, etc.)
    - user_groups: list of group strings for ACL-aware search (if you’re using access control)
    """
    args = {
        "IndexId": INDEX_ID,
        "QueryText": query_text,
        "PageSize": page_size,
    }

    if query_filter:
        args["AttributeFilter"] = query_filter

    if user_groups:
        args["UserContext"] = {"Groups": user_groups}

    try:
        resp = client.query(**args)
        print("RES",resp)
    except ClientError as e:
        print(f"Query failed: {e.response.get('Error', {}).get('Message', str(e))}")
        return

    # Extract and print “Answer” and “Document” results
    for item in resp.get("ResultItems", []):
        rtype = item.get("Type")  # "ANSWER" | "DOCUMENT" | "QUESTION_ANSWER" | "TABLE"
        score = item.get("ScoreAttributes", {}).get("ScoreConfidence")
        if rtype in ("ANSWER", "QUESTION_ANSWER"):
            text = item.get("AdditionalAttributes", [])
            answer_text = None
            for aa in text:
                if aa.get("Key") == "AnswerText":
                    answer_text = aa.get("Value", {}).get("TextWithHighlightsValue", {}).get("Text")
            print(f"[{rtype}] ({score}) {answer_text}")
        elif rtype == "DOCUMENT":
            doc = item.get("DocumentTitle", {}).get("Text") or "(untitled)"
            uri = item.get("DocumentURI")
            # Optional: fields such as SourceAttribution and DocumentAttributes:
            print(f"[DOC]   ({score}) {doc} — {uri}")

# Example call
run_query("How much is the book transfer credit for a new business policy?", page_size=5)
# Out:
# RES {'QueryId': '2bf2a87f-0e87-43e5-9147-4355ccfcdb67', 'ResultItems': [{'Id': '2bf2a87f-0e87-43e5-9147-4355ccfcdb67-1154761e-8a15-4298-8573-b3cc4d638096', 'Type': 'ANSWER', 'Format': 'TEXT', 'AdditionalAttributes': [{'Key': 'AnswerText', 'ValueType': 'TEXT_WITH_HIGHLIGHTS_VALUE', 'Value': {'TextWithHighlightsValue': {'Text': '\nDorchester Mutual Insurance Companies. \n\n\nEndorsement: HO-LF \n\n\n  \n\n\n\n\n\n\n\nNJ PERSONAL LINES MANUAL \n\n\nFITCHBURG MUTUAL INSURANCE CO.  HO • R 9 \n\n\n \n\n\n \nEd. 5.0 \n\n\n© 2017 MSO®, Inc. \n\n\n24.0  BOOK TRANSFER CREDIT \n\n\nA 10% credit applies to new business that is part of an agreed book transfer from a designated company in \n\n\nthe agent’s office. Credit applies to new business and to the next 4 renewals as follows: \n\n\n Credit % \nNew Business 10% \n\n\n1st renewal 8% \n\n\n2nd renewal 6% \n\n\n3rd renewal 4% \n\n\n4th renewal 2% \n\n\n5th renewal deleted \nEndorsement: BTC 09 \n\n\nCannot be applied concurrently with the Agency Loyalty Credit. \n\n\n \n\n\n25.0  ACCOUNT CREDIT \n\n\nThe following credit applies to the base premium if the insured or spouse has 1 or more of the \n\n\nfollowingpolicies with Fitchburg Mutual, for a primary residence only: \n\n\n• Businessowners (ComPak®); \n\n\n• Commercial Auto; \n\n\n• Commercial Package; \n\n\n• Dwelling Fire; \n\n\n• Personal Auto; \n\n\n• Workers Compensation (WorkPak®). \n\n\nCoastal Risks 7.5% \n\n\nNon-Coastal Risks 10%', 'Highlights': [{'BeginOffset': 216, 'EndOffset': 219, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 191, 'EndOffset': 195, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 196, 'EndOffset': 204, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 205, 'EndOffset': 211, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 221, 'EndOffset': 227, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 239, 'EndOffset': 242, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 243, 'EndOffset': 251, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 278, 'EndOffset': 282, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 283, 'EndOffset': 291, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 344, 'EndOffset': 350, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 362, 'EndOffset': 365, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 366, 'EndOffset': 374, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 418, 'EndOffset': 424, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 428, 'EndOffset': 431, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 432, 'EndOffset': 440, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 619, 'EndOffset': 625, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 648, 'EndOffset': 654, 'TopAnswer': False, 'Type': 'STANDARD'}, {'BeginOffset': 672, 'EndOffset': 678, 'TopAnswer': False, 'Type': 'STANDARD'}]}}}], 'DocumentId': 's3://evoq-ndgroup-documents/NandD-files-documents/Agency Manual NJ Combined Files/NJ FMIC HO Rates NJ Proposed 12-1-24 complete set.pdf', 'DocumentTitle': {'Text': 'NJ FMIC HO Rates NJ Proposed 12-1-24 complete set.pdf', 'Highlights': []}, 'DocumentExcerpt': {'Text': '\nDorchester Mutual Insurance Companies. \n\n\nEndorsement: HO-LF \n\n\n  \n\n\n\n\n\n\n\nNJ PERSONAL LINES MANUAL \n\n\nFITCHBURG MUTUAL INSURANCE CO.  HO • R 9 \n\n\n \n\n\n \nEd. 5.0 \n\n\n© 2017 MSO®, Inc. \n\n\n24.0  BOOK TRANSFER CREDIT \n\n\nA 10% credit applies to new business that is part of an agreed book transfer from a d', 'Highlights': [{'BeginOffset': 0, 'EndOffset': 300, 'TopAnswer': False, 'Type': 'STANDARD'}]}, 'DocumentURI': 'https://evoq-ndgroup-documents.s3.amazonaws.com/NandD-files-documents/Agency%20Manual%20NJ%20Combined%20Files/NJ%20FMIC%20HO%20Rates%20NJ%20Proposed%2012-1-24%20complete%20set.pdf', 'DocumentAttributes': [{'Key': '_source_uri', 'Value': {'StringValue': 'https://evoq-ndgroup-documents.s3.amazonaws.com/NandD-files-documents/Agency%20Manual%20NJ%20Comb ...
# [ANSWER] (HIGH)
# Dorchester Mutual Insurance Companies.
#
#
# Endorsement: HO-LF
#
#
#
#
#
#
#
#
#
#
# NJ PERSONAL LINES MANUAL
#
#
# FITCHBURG MUTUAL INSURANCE CO.  HO • R 9
#
#
#
#
#
#
# Ed. 5.0
#
#
# © 2017 MSO®, Inc.
#
#
# 24.0  BOOK TRANSFER CREDIT
#
#
# A 10% credit applies to new business that is part of an agreed book transfer from a designated company in
#
#
# the agent’s office. Credit applies to new business and to the next 4 renewals as follows:
#
#
#  Credit %
# New Business 10%
#
#
# 1st renewal 8%
#
#
# 2nd renewal 6%
#
#
# 3rd renewal 4%
#
#
# 4th renewal 2%
#
#
# 5th renewal deleted
# Endorsement: BTC 09
#
#
# Cannot be applied concurrently with the Agency Loyalty Credit.
#
#
#
#
#
# 25.0  ACCOUNT CREDIT
#
#
# The following credit applies to the base premium if the insured or spouse has 1 or more of the
#
#
# followingpolicies with Fitchburg Mutual, for a primary residence only:
#
#
# • Businessowners (ComPak®);
#
#
# • Commercial Auto;
#
#
# • Commercial Package;
#
#
# • Dwelling Fire;
#
#
# • Personal Auto;
#
#
# • Workers Compensation (WorkPak®).
#
#
# Coastal Risks 7.5%
#
#
# Non-Coastal Risks 10%
# [ANSWER] (MEDIUM)
# Rental to Others Theft
#
#
# Coverage
#
#
# 1st & 2nd  29 29
#
#
# 3rd & Greater 50 25
#
#
# Section II @ $100,000
#
#
# Cov. E
#
#
# 1st & 2nd  29 29
#
#
# 3rd & Greater 75 60
#
#
#
#
#
#
#
#
#  Endorsements: HO-888
#
#
#     HO 05 41
#
#
#
#
#
#
#
#
#
#
#
#
#
# HOMEOWNER EXCEPTION PAGES
#
#
#
# MASSACHUSETTS  AS OF 2/1/2021
#
#
#
#
#
#
#  Norfolk & Dedham Mutual Fire Insurance Company
#  Dorchester Mutual Insurance Company
#
#
#
#
#
#
# 4. BOOK TRANSFER CREDIT
#
#
# Credit applies to new business that is part of an agreed book transfer from a designated company in
#
#
# the agent’s office.  The Book Transfer Credit cannot be applied concurrently with the Agency
#
#
# Loyalty Credit.
#
#
#
#
#
# Each Policy, which the agent includes as part of the book transfer, shall receive the same credit
#
#
# endorsement. The credit endorsement utilized shall be agreed upon by the agent and N&D® prior to
#
#
# the effective date of the book transfer.  The credit is determined by multiplying the % associated
#
#
# with the applicable endorsements (shown in the table below) by the policy base premium.
#
#
#
#
#
# A B C D E
#
#
# YEARS
#
#
# WITH N&D®
#
#
# GROUP (#)
#
#
# ENDORSEMENT (%)
#
#
# BT 13 20
#
#
#
#
#
# BT 13 15
# [ANSWER] (MEDIUM)
# 8 8%
#
#
#  9 9%
#
#
#  10 10%
#
#
#
#
#
# If the insured has been insured less than 5 years with the N & D Group, but 5+ years loss free
#
#
# while continuously insured under Homeowners policies, a 5% Loss Free credit will apply. Form
#
#
# HO-LF2 must be signed by the insured. Credit will increase by 1% at each subsequent renewal for
#
#
# each additional loss free year up to the maximum 10% credit.
#
#
# “Loss free” means no paid or open claims. Personal Umbrella claims are not included.
#
#
# “Norfolk & Dedham Group” means the Norfolk & Dedham Mutual Fire, Fitchburg Mutual, or
#
#
# Dorchester Mutual Insurance Companies.
#
#
# Endorsement: HO-LF
#
#
#
#
#
#
#
#
#
#
# NJ PERSONAL LINES MANUAL
#
#
# FITCHBURG MUTUAL INSURANCE CO.  HO • R 9
#
#
#
#
#
#
# Ed. 5.0
#
#
# © 2017 MSO®, Inc.
#
#
# 24.0  BOOK TRANSFER CREDIT
#
#
# A 10% credit applies to new business that is part of an agreed book transfer from a designated company in
#
#
# the agent’s office. Credit applies to new business and to the next 4 renewals as follows:
#
#
#  Credit %
# New Business 10%
#
#
# 1st renewal 8%
#
#
# 2nd renewal 6%
# [DOC]   (HIGH) BT_13_20_01_14.pdf — https://evoq-ndgroup-documents.s3.amazonaws.com/NandD-files-documents/Agency%20Manual%20MA%20Combines%20Files/BT_13_20_01_14.pdf
# [DOC]   (HIGH) BT_13_10_01_14.pdf — https://evoq-ndgroup-documents.s3.amazonaws.com/NandD-files-documents/Agency%20Manual%20MA%20Combines%20Files/BT_13_10_01_14.pdf
